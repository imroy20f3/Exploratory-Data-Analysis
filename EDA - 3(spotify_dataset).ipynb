# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('spotify_churn_dataset.csv')

# %%
df.head()
# Out:
#    user_id  gender  age country subscription_type  listening_time  \
# 0        1  Female   54      CA              Free              26
# 1        2   Other   33      DE            Family             141
# 2        3    Male   38      AU           Premium             199
# 3        4  Female   22      CA           Student              36
# 4        5   Other   29      US            Family             250
#
#    songs_played_per_day  skip_rate device_type  ads_listened_per_week  \
# 0                    23       0.20     Desktop                     31
# 1                    62       0.34         Web                      0
# 2                    38       0.04      Mobile                      0
# 3                     2       0.31      Mobile                      0
# 4                    57       0.36      Mobile                      0
#
#    offline_listening  is_churned
# 0                  0           1
# 1                  1           0
# 2                  1           1
# ...

# %%
df.sample(10)
# Out:
#       user_id  gender  age country subscription_type  listening_time  \
# 7277     7278  Female   33      AU            Family              45
# 7503     7504   Other   49      DE           Student             233
# 6074     6075   Other   40      CA            Family              80
# 3542     3543    Male   37      DE              Free             278
# 2413     2414  Female   44      US           Student             105
# 368       369   Other   50      FR            Family             224
# 5612     5613   Other   37      PK           Premium              12
# 216       217   Other   32      FR              Free             204
# 3759     3760    Male   51      AU           Premium              36
# 359       360  Female   49      DE            Family              61
#
#       songs_played_per_day  skip_rate device_type  ads_listened_per_week  \
# 7277                    11       0.15         Web                      0
# ...

# %%
df.isnull().sum()
# Out:
# user_id                  0
# gender                   0
# age                      0
# country                  0
# subscription_type        0
# listening_time           0
# songs_played_per_day     0
# skip_rate                0
# device_type              0
# ads_listened_per_week    0
# offline_listening        0
# is_churned               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   user_id                8000 non-null   int64
#  1   gender                 8000 non-null   object
#  2   age                    8000 non-null   int64
#  3   country                8000 non-null   object
#  4   subscription_type      8000 non-null   object
#  5   listening_time         8000 non-null   int64
#  6   songs_played_per_day   8000 non-null   int64
#  7   skip_rate              8000 non-null   float64
#  8   device_type            8000 non-null   object
#  9   ads_listened_per_week  8000 non-null   int64
#  10  offline_listening      8000 non-null   int64
#  11  is_churned             8000 non-null   int64
# dtypes: float64(1), int64(7), object(4)
# memory usage: 750.1+ KB

# %%
df.describe()
# Out:
#           user_id          age  listening_time  songs_played_per_day  \
# count  8000.00000  8000.000000     8000.000000           8000.000000
# mean   4000.50000    37.662125      154.068250             50.127250
# std    2309.54541    12.740359       84.015596             28.449762
# min       1.00000    16.000000       10.000000              1.000000
# 25%    2000.75000    26.000000       81.000000             25.000000
# 50%    4000.50000    38.000000      154.000000             50.000000
# 75%    6000.25000    49.000000      227.000000             75.000000
# max    8000.00000    59.000000      299.000000             99.000000
#
#          skip_rate  ads_listened_per_week  offline_listening   is_churned
# count  8000.000000            8000.000000        8000.000000  8000.000000
# mean      0.300127               6.943875           0.747750     0.258875
# std       0.173594              13.617953           0.434331     0.438044
# ...

# %%
df.shape
# Out:
# (8000, 12)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
sns.countplot(data = df, x = 'is_churned')
# Out:
# <Axes: xlabel='is_churned', ylabel='count'>

# %%
sns.countplot(data = df, x = 'offline_listening')
# Out:
# <Axes: xlabel='offline_listening', ylabel='count'>

# %%
sns.countplot(data = df, x = 'gender')
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
df['country'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='country'>

# %%
df['country'].value_counts().plot(kind ='pie',autopct ='%0.2f%%',ylabel='')
# Out:
# <Axes: >

# %%
df['subscription_type'].value_counts().plot(kind ='pie',autopct ='%0.2f%%',ylabel='')
# Out:
# <Axes: >

# %%
df['device_type'].value_counts().plot(kind ='pie',autopct ='%0.2f%%',ylabel='')
# Out:
# <Axes: >

# %%
df['offline_listening'].value_counts().plot(kind ='pie',autopct ='%0.2f%%',ylabel='')
# Out:
# <Axes: >

# %%
df['is_churned'].value_counts().plot(kind ='pie',autopct ='%0.2f%%',ylabel='')
# Out:
# <Axes: >

# %%
sns.histplot(data = df, x = 'age',kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.displot(data = df, x = 'age', kind = 'kde')

# %%
sns.displot(data = df, x = 'listening_time', kind = 'hist')

# %%
sns.boxplot(x=df['listening_time'])
# Out:
# <Axes: xlabel='listening_time'>

# %%
sns.kdeplot(df['songs_played_per_day'], shade=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7420\3636376624.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['songs_played_per_day'], shade=True)
# <Axes: xlabel='songs_played_per_day', ylabel='Density'>

# %%
df['skip_rate'].plot(kind='hist', bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.lineplot(x= 'songs_played_per_day',y = 'listening_time', data = df)
# Out:
# <Axes: xlabel='songs_played_per_day', ylabel='listening_time'>

# %%
sns.heatmap(df[['songs_played_per_day', 'listening_time', 'age']].corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.barplot(data = df, x= 'gender', y = 'age')
# Out:
# <Axes: xlabel='gender', ylabel='age'>

# %%
sns.boxplot(data=df, x='is_churned', y='listening_time')
# Out:
# <Axes: xlabel='is_churned', ylabel='listening_time'>

# %%
sns.violinplot(data=df, x='gender', y='listening_time')
# Out:
# <Axes: xlabel='gender', ylabel='listening_time'>

# %%
pd.crosstab(df['gender'], df['is_churned']).plot(kind='bar', stacked=True)
sns.heatmap(pd.crosstab(df['subscription_type'], df['is_churned']), annot=True, fmt='d', cmap='Greens')
# Out:
# <Axes: xlabel='is_churned', ylabel='subscription_type'>

# %%
sns.countplot(data=df, x='country', hue='is_churned')
# Out:
# <Axes: xlabel='country', ylabel='count'>

# %%
sns.countplot(data=df, x='country', hue='subscription_type')
# Out:
# <Axes: xlabel='country', ylabel='count'>

# %%
sns.pairplot(df[['songs_played_per_day', 'listening_time', 'age','is_churned']], hue='is_churned')

# %%
sns.barplot(data=df, x='subscription_type', y='songs_played_per_day', hue='is_churned')
# Out:
# <Axes: xlabel='subscription_type', ylabel='songs_played_per_day'>

# %%
sns.catplot(data=df, x='gender', y='listening_time', hue='is_churned', col='subscription_type', kind='bar')

# %%
sns.histplot(data=df, x='listening_time', hue='is_churned', kde=True)
# Out:
# <Axes: xlabel='listening_time', ylabel='Count'>
